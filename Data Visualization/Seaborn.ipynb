# %% [markdown]
# <img src="../imgs/CampQMIND_banner.png">

# %% [markdown]
# This Jupyter Lab notebook goes over how to plot with Seaborn library in Python. This guide includes some of the basics in setting up your plots and customizing its style to match your needs. Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics. For more information on the seaborn library and the plots seen in this notebook visit https://seaborn.pydata.org/index.html or https://seaborn.pydata.org/api.html (for the different plot types)

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Basics:-Style,-Color,-and-Utility-Functions" data-toc-modified-id="Basics:-Style,-Color,-and-Utility-Functions-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Basics: Style, Color, and Utility Functions</a></span><ul class="toc-item"><li><span><a href="#Style" data-toc-modified-id="Style-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Style</a></span></li><li><span><a href="#Color" data-toc-modified-id="Color-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Color</a></span></li><li><span><a href="#Utility" data-toc-modified-id="Utility-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Utility</a></span></li></ul></li><li><span><a href="#Plots" data-toc-modified-id="Plots-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Relational" data-toc-modified-id="Relational-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Relational</a></span><ul class="toc-item"><li><span><a href="#LinePlot" data-toc-modified-id="LinePlot-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>LinePlot</a></span></li><li><span><a href="#Scatterplot" data-toc-modified-id="Scatterplot-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Scatterplot</a></span></li><li><span><a href="#Relplot" data-toc-modified-id="Relplot-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Relplot</a></span></li></ul></li><li><span><a href="#Categorical" data-toc-modified-id="Categorical-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Categorical</a></span><ul class="toc-item"><li><span><a href="#Catplot" data-toc-modified-id="Catplot-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Catplot</a></span></li><li><span><a href="#Stripplot" data-toc-modified-id="Stripplot-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Stripplot</a></span></li><li><span><a href="#Swarmplot" data-toc-modified-id="Swarmplot-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Swarmplot</a></span></li><li><span><a href="#Boxplot" data-toc-modified-id="Boxplot-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Boxplot</a></span></li><li><span><a href="#Violinplot" data-toc-modified-id="Violinplot-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Violinplot</a></span></li><li><span><a href="#Boxenplot" data-toc-modified-id="Boxenplot-2.2.6"><span class="toc-item-num">2.2.6&nbsp;&nbsp;</span>Boxenplot</a></span></li><li><span><a href="#Pointplot" data-toc-modified-id="Pointplot-2.2.7"><span class="toc-item-num">2.2.7&nbsp;&nbsp;</span>Pointplot</a></span></li><li><span><a href="#Barplot" data-toc-modified-id="Barplot-2.2.8"><span class="toc-item-num">2.2.8&nbsp;&nbsp;</span>Barplot</a></span></li><li><span><a href="#Countplot" data-toc-modified-id="Countplot-2.2.9"><span class="toc-item-num">2.2.9&nbsp;&nbsp;</span>Countplot</a></span></li></ul></li><li><span><a href="#Distribution" data-toc-modified-id="Distribution-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Distribution</a></span><ul class="toc-item"><li><span><a href="#distplot" data-toc-modified-id="distplot-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>distplot</a></span></li><li><span><a href="#Kdeplot" data-toc-modified-id="Kdeplot-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Kdeplot</a></span></li></ul></li><li><span><a href="#Regression" data-toc-modified-id="Regression-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Regression</a></span></li><li><span><a href="#lmplot" data-toc-modified-id="lmplot-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>lmplot</a></span><ul class="toc-item"><li><span><a href="#regplot" data-toc-modified-id="regplot-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>regplot</a></span></li></ul></li><li><span><a href="#Matrix" data-toc-modified-id="Matrix-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Matrix</a></span><ul class="toc-item"><li><span><a href="#heatmap" data-toc-modified-id="heatmap-2.6.1"><span class="toc-item-num">2.6.1&nbsp;&nbsp;</span>heatmap</a></span></li><li><span><a href="#clustermap" data-toc-modified-id="clustermap-2.6.2"><span class="toc-item-num">2.6.2&nbsp;&nbsp;</span>clustermap</a></span></li><li><span><a href="#MultiGrid-Grids" data-toc-modified-id="MultiGrid-Grids-2.6.3"><span class="toc-item-num">2.6.3&nbsp;&nbsp;</span>MultiGrid Grids</a></span></li><li><span><a href="#Facet-Grids" data-toc-modified-id="Facet-Grids-2.6.4"><span class="toc-item-num">2.6.4&nbsp;&nbsp;</span>Facet Grids</a></span></li><li><span><a href="#Pair-Grids" data-toc-modified-id="Pair-Grids-2.6.5"><span class="toc-item-num">2.6.5&nbsp;&nbsp;</span>Pair Grids</a></span></li><li><span><a href="#Joint-Grids" data-toc-modified-id="Joint-Grids-2.6.6"><span class="toc-item-num">2.6.6&nbsp;&nbsp;</span>Joint Grids</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# First Step: Install Seaborn
#
# - if you have Conda use: conda install seaborn
# - if you have Pip use: pip install seaborn
#
# For more help visit: https://seaborn.pydata.org/installing.html

# %%
# You will also need to import some of these common libraries
import scipy as sp
import pandas as pd
import numpy as np
import math
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %% [markdown]
# # Basics: Style, Color, and Utility Functions

# %% [markdown]
# ## Style

# %% [markdown]
# For more info visit: https://seaborn.pydata.org/tutorial/aesthetics.html

# %% [markdown]
# ## Color

# %% [markdown]
# For more info visit: https://seaborn.pydata.org/tutorial/color_palettes.html

# %% [markdown]
# Set the matplotlib color cycle using a seaborn palette.
# set_palette(palette, n_colors=None, desat=None, color_codes=False)
#
# Inputs:
# - n_colorsint : Number of colors in the cycle. The default number of colors will depend on the format of palette, see the color_palette() documentation for more information.
#
# - desatfloat : Proportion to desaturate each color by.
#
# - color_codesbool : If True and palette is a seaborn palette, remap the shorthand color codes (e.g. “b”, “g”, “r”, etc.) to the colors from this palette.

# %%
#sns.set_palette("Blues")
#sns.set_palette("Set1",8, .75)

# %% [markdown]
# Inputs:
# - palette: None, string, or sequence, optional
# Name of palette or None to return current palette. If a sequence, input colors are used but possibly cycled and desaturated.
#
# - n_colorsint, optional
# Number of colors in the palette. If None, the default will depend on how palette is specified. Named palettes default to 6 colors, but grabbing the current palette or passing in a list of colors will not change the number of colors unless this is specified. Asking for more colors than exist in the palette will cause it to cycle.
#
# - desatfloat, optional
# Proportion to desaturate each color by.
#
# Returns:
#
# - palettelist of RGB tuples.
# Color palette. Behaves like a list, but can be used as a context manager and possesses an as_hex method to convert to hex color codes.
#
# *note: you can also write "color.palette("paste")" [or deep, muted, bright, pastel, dark, colorblind.] to get a specific predetermined color palette.*

# %% [markdown]
# ## Utility

# %%
#If you want to load an example dataset from the online repository (requires internet)
sns.load_dataset 
#If you want to report available example datasets, useful for reporting issues." 
sns.get_dataset_names
# Out:
# <function seaborn.utils.get_dataset_names()>

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/api.html#utility-functions

# %% [markdown]
# # Plots

# %% [markdown]
# ## Relational

# %% [markdown]
# ### LinePlot

# %% [markdown]
# Example: The following lineplot, using the fmri dataset, draws a single line plot, of signal vs. timepoint, with error bands showing a confidence interval.

# %%
fmri = sns.load_dataset("fmri")
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)

# %% [markdown]
# For more information check out: https://seaborn.pydata.org/generated/seaborn.lineplot.html#seaborn.lineplot

# %% [markdown]
# ### Scatterplot

# %% [markdown]
# Example: The following scatterplot, using the tips dataset, draws a simple scatter plot between two variables: tip vs. total_bill.

# %%
tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# For more Information check out: https://seaborn.pydata.org/generated/seaborn.scatterplot.html#seaborn.scatterplot

# %% [markdown]
# ### Relplot

# %% [markdown]
# *This function provides access to several different axes-level functions that show the relationship between two variables with semantic mappings of subsets.*

# %% [markdown]
# Example: The following relplot, using the tips dataset, draws a single facet to use the FacetGrid legend placement. The data is grouped into days by their respective colors.

# %%
sns.set(style="ticks")
tips = sns.load_dataset("tips")
g = sns.relplot(x="total_bill", y="tip", hue="day", data=tips)

# %% [markdown]
# For more Information Check out:https://seaborn.pydata.org/generated/seaborn.relplot.html#seaborn.relplot

# %% [markdown]
# ## Categorical

# %% [markdown]
# ### Catplot

# %% [markdown]
# *This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations.*

# %% [markdown]
# Example: The following catplot, using the excercise dataset, draws a single facet to use the FacetGrid legend placement. The data is grouped into the kind of excercise by their respective colors. The plot is a pulse vs. time graph.

# %%
sns.set(style="ticks")
exercise = sns.load_dataset("exercise")
g = sns.catplot(x="time", y="pulse", hue="kind", data=exercise)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.catplot.html#seaborn.catplot

# %% [markdown]
# ### Stripplot

# %% [markdown]
# *Draw a scatterplot where one variable is categorical.*

# %% [markdown]
# Example: The following stripplot, using the tips dataset, draws a plot graphing the different strips by a categorical variable. The plot is total_bill vs. day, where the data is grouped by their respective colors.

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.stripplot(x=tips["total_bill"])

# %%
ax = sns.stripplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.stripplot.html#seaborn.stripplot

# %% [markdown]
# ### Swarmplot

# %% [markdown]
# *This function is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, but it does not scale well to large numbers of observations. *

# %% [markdown]
# Example: The following swarmplot, using the tips dataset, draws a plot graphing the different swarms by a categorical variable. The plot is total_bill vs. day, where the data is grouped by their respective colors. [This is very similar to the stripplot]

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.swarmplot(x=tips["total_bill"])

# %%
ax = sns.swarmplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.swarmplot.html#seaborn.swarmplot

# %% [markdown]
# ### Boxplot

# %% [markdown]
# *A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range. This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type.*

# %% [markdown]
# Example: The following boxplot, using the tips dataset, draws a plot of tips vs. day, where the data is grouped by days.

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.boxplot(x=tips["total_bill"])

# %%
ax = sns.boxplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot

# %% [markdown]
# ### Violinplot

# %% [markdown]
# *A violin plot plays a similar role as a box and whisker plot. It shows the distribution of quantitative data across several levels of one (or more) categorical variables such that those distributions can be compared. Unlike a box plot, in which all of the plot components correspond to actual datapoints, the violin plot features a kernel density estimation of the underlying distribution. This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type.

# %% [markdown]
# Example: The following violinplot, using the tips dataset, creates a plot of total_bill vs.day and groups the data by the specific day.

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x=tips["total_bill"])

# %%
ax = sns.violinplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.violinplot.html#seaborn.violinplot

# %% [markdown]
# ### Boxenplot

# %% [markdown]
# *This style of plot was originally named a “letter value” plot because it shows a large number of quantiles that are defined as “letter values”. It is similar to a box plot in plotting a nonparametric representation of a distribution in which all features correspond to actual observations. By plotting more quantiles, it provides more information about the shape of the distribution, particularly in the tails. This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type.*

# %% [markdown]
# Example: The following boxenplot, using the tips dataset, creates a plot of total_bill vs. day. The data is categorized into specific days, which can be seen by their respective colors.

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.boxenplot(x=tips["total_bill"])
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %%
ax = sns.boxenplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.pointplot.html#seaborn.pointplot

# %% [markdown]
# ### Pointplot

# %% [markdown]
# *A point plot represents an estimate of central tendency for a numeric variable by the position of scatter plot points and provides some indication of the uncertainty around that estimate using error bars.*
#
# Point plots can be more useful than bar plots for focusing comparisons between different levels of one or more categorical variables. They are particularly adept at showing interactions: how the relationship between levels of one categorical variable changes across levels of a second categorical variable. The lines that join each point from the same hue level allow interactions to be judged by differences in slope, which is easier for the eyes than comparing the heights of several groups of points or bars.
#
# It is important to keep in mind that a point plot shows only the mean (or other estimator) value, but in many cases it may be more informative to show the distribution of values at each level of the categorical variables. In that case, other approaches such as a box or violin plot may be more appropriate.
#
# This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type.

# %% [markdown]
# Example: The following pointplot, using the tips dataset, draws a set of vertical point plots grouped by a categorical variable (time).

# %%
sns.set(style="darkgrid")
tips = sns.load_dataset("tips")
ax = sns.pointplot(x="time", y="total_bill", data=tips)

# %%
ax = sns.pointplot(x="time", y="total_bill", hue="smoker", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.pointplot.html#seaborn.pointplot

# %% [markdown]
# ### Barplot

# %% [markdown]
# *A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle and provides some indication of the uncertainty around that estimate using error bars. Bar plots include 0 in the quantitative axis range, and they are a good choice when 0 is a meaningful value for the quantitative variable, and you want to make comparisons against it.*
#
# For datasets where 0 is not a meaningful value, a point plot will allow you to focus on differences between levels of one or more categorical variables.
#
# It is also important to keep in mind that a bar plot shows only the mean (or other estimator) value, but in many cases it may be more informative to show the distribution of values at each level of the categorical variables. In that case, other approaches such as a box or violin plot may be more appropriate.
#
# This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type.

# %% [markdown]
# Example: The following barplot, using the tips dataset, draws a set of vertical bar plots grouped by a categorical variable (day). The black lines represent the error in the dataset.

# %%
sns.set(style="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.barplot(x="day", y="total_bill", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.barplot.html#seaborn.barplot

# %% [markdown]
# ### Countplot

# %% [markdown]
# *A count plot can be thought of as a histogram across a categorical, instead of quantitative, variable.*
#
# This function always treats one of the variables as categorical and draws data at ordinal positions (0, 1, … n) on the relevant axis, even when the data has a numeric or date type

# %% [markdown]
# Example: the following countplot, using the titanic dataset, shows value counts for a single categorical variable (class). The data is separated by their respective color.

# %%
sns.set(style="darkgrid")
titanic = sns.load_dataset("titanic")
ax = sns.countplot(x="class", data=titanic)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.countplot.html#seaborn.countplot

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### distplot

# %% [markdown]
# *This function combines the matplotlib hist function (with automatic calculation of a good default bin size) with the seaborn kdeplot() and rugplot() functions.*

# %% [markdown]
# Example: The following distplot shows a default plot with a kernel density estimate and histogram with bin size determined automatically with a reference rule.

# %%
sns.set(); np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.distplot.html#seaborn.distplot

# %% [markdown]
# ### Kdeplot

# %% [markdown]
# *This function fits and plots a univariate or bivariate kernel density estimate.*

# %% [markdown]
# Example: The following kdeplot plots a basic univariate density.

# %%
np.random.seed(10)
sns.set(color_codes=True)
mean, cov = [0, 2], [(1, .5), (.5, 1)]
x, y = np.random.multivariate_normal(mean, cov, size=50).T
ax = sns.kdeplot(x)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.kdeplot.html#seaborn.kdeplot

# %% [markdown]
# ## Regression

# %% [markdown]
# ## lmplot

# %% [markdown]
# *This function combines regplot() and FacetGrid. It is intended as a convenient interface to fit regression models across conditional subsets of a dataset.*

# %% [markdown]
# Example: The following lmplot shows a basic regression model plot.

# %%
sns.set(color_codes=True)
tips = sns.load_dataset("tips")
g = sns.lmplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.lmplot.html#seaborn.lmplot

# %% [markdown]
# ### regplot

# %% [markdown]
# *This function plots data and a linear regression model fit.*

# %% [markdown]
# Example: The following regplot, using the tips dataset, plots the relationship between two variables in a DataFrame (tip vs. total_bill).

# %%
sns.set(color_codes=True)
tips = sns.load_dataset("tips")
ax = sns.regplot(x="total_bill", y="tip", data=tips)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.regplot.html#seaborn.regplot

# %% [markdown]
# ## Matrix

# %% [markdown]
# ### heatmap

# %% [markdown]
# *This function plots rectangular data as a color-encoded matrix.*

# %% [markdown]
# Example: The following heatmap plots a heatmap for a numpy array.

# %%
np.random.seed(0)
sns.set()
uniform_data = np.random.rand(10, 12)
ax = sns.heatmap(uniform_data)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.heatmap.html#seaborn.heatmap

# %% [markdown]
# ### clustermap

# %% [markdown]
# *This function plots a matrix dataset as a hierarchically-clustered heatmap.*

# %% [markdown]
# Example: The following clustermap plots a clustered heatmap, categorized by sepal length, sepal width, petal length, and petal width.

# %%
sns.set(color_codes=True)
iris = sns.load_dataset("iris")
species = iris.pop("species")
g = sns.clustermap(iris)

# %% [markdown]
# For more information, check out: https://seaborn.pydata.org/generated/seaborn.clustermap.html#seaborn.clustermap

# %% [markdown]
# ### MultiGrid Grids

# %% [markdown]
# MultiGrid Grids are just fancy ways of showing various relationships between different sets of data. Below are three examples of the different types of plots you could make. To find out more information on each click the links below them.

# %% [markdown]
# ### Facet Grids

# %% [markdown]
# *This class maps a dataset onto multiple axes arrayed in a grid of rows and columns that correspond to levels of variables in the dataset.*

# %% [markdown]
# Example: The following FacetGrid creates a 2x2 grid of facets using the tips dataset. It also draws a univariate plot on each facet. The grid's rows are organized by if customers were smokers and the columns are organized by the time of day. The plots themselves show the total bill vs. the number of people.

# %%
g = sns.FacetGrid(tips, col="time",  row="smoker")
g = g.map(plt.hist, "total_bill")

# %% [markdown]
# For more information: https://seaborn.pydata.org/generated/seaborn.FacetGrid.html#seaborn.FacetGrid

# %% [markdown]
# ### Pair Grids

# %% [markdown]
# *This class maps each variable in a dataset onto a column and row in a grid of multiple axes. Different axes-level plotting functions can be used to draw bivariate plots in the upper and lower triangles, and the the marginal distribution of each variable can be shown on the diagonal.*

# %% [markdown]
# Example: The following PairGrid draws scatterplots for joint relationships and histograms for univariate distributions, using the iris dataset. The rows and columns are organized by sepal length, sepal width, petal length, and petal length. WHen the plot is graphing the same variable vs. itself, it draws a histogram instead of a scatterplot.

# %%
sns.set(style="ticks", color_codes=True)
iris = sns.load_dataset("iris")
g = sns.pairplot(iris)

# %% [markdown]
# For more information: https://seaborn.pydata.org/generated/seaborn.pairplot.html#seaborn.pairplot

# %% [markdown]
# ### Joint Grids

# %% [markdown]
# *Grid for drawing a bivariate plot with marginal univariate plots.*

# %% [markdown]
# Example: The following JointGrid plots data and a linear regression model fit while also drawing a
#  univariate distribution of observations (refer to distplot for more information).

# %%
g = sns.JointGrid(x="total_bill", y="tip", data=tips)
g = g.plot(sns.regplot, sns.distplot)

# %% [markdown]
# For more information: https://seaborn.pydata.org/generated/seaborn.JointGrid.html#seaborn.JointGrid
