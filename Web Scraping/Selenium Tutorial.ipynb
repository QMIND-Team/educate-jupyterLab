# %% [markdown]
# # Selenium Tutorial
# ## By Travis Cossarini
#
# ### Table of Contents
#
# Selenium is a very powerful tool for the automation of web based testing. It is also extremely useful in the creation of web crawlers and automation of web based tasks.
#
# In this notebook we will learn how to use Selenium for:
# <ol>
#     <li>Setup</li>
#     <li>Basics</li>
#     <li>Website Interaction</li>
#     <li>Scraping</li>
#     <li>Automated Testing</li>
#
# </ol>

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Selenium-Tutorial" data-toc-modified-id="Selenium-Tutorial-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Selenium Tutorial</a></span><ul class="toc-item"><li><span><a href="#By-Travis-Cossarini" data-toc-modified-id="By-Travis-Cossarini-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>By Travis Cossarini</a></span><ul class="toc-item"><li><span><a href="#Table-of-Contents" data-toc-modified-id="Table-of-Contents-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Table of Contents</a></span></li></ul></li></ul></li><li><span><a href="#Setup" data-toc-modified-id="Setup-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Setup</a></span></li><li><span><a href="#Basics" data-toc-modified-id="Basics-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Basics</a></span></li><li><span><a href="#Website-Interaction" data-toc-modified-id="Website-Interaction-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Website Interaction</a></span></li><li><span><a href="#Scraping" data-toc-modified-id="Scraping-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Scraping</a></span></li><li><span><a href="#Automated-Testing" data-toc-modified-id="Automated-Testing-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Automated Testing</a></span></li></ul></div>

# %% [markdown]
# # Setup
#
# To start you will need to install both Selenium (Pip or Conda) and a webdriver (we'll be using Chrome). See below for a tutorial on setting up the webdriver:
# https://www.youtube.com/watch?v=dz59GsdvUF8
#
# You can use any webdriver/broswer combo you would like, the syantax is largely the same.
#
# After adding the folder to PATH, you will need to restart your computer for the change to take effect.
#
# An alternative to adding the webdriver to your path is the specify the location of the webdriver file in the instantiation of each instance. However, this is not what I have opted for in this tutorial.

# %% [markdown]
# # Basics

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import time

# %% [markdown]
# Lets do a google search for a selenium tutorial.

# %%
driver = webdriver.Chrome()
driver.maximize_window()
driver.get("https://google.com") # opens google

search_bar = driver.find_element_by_name("q")
search_bar.clear()
search_bar.send_keys("Python Selenium youtube tutorial") # enters the text
search_bar.submit() #submits request
time.sleep(2)
driver.find_element_by_xpath('//div[@class="r"]/a/h3').click()

time.sleep(10)
driver.close()

# %% [markdown]
# There we go, lesson over lol.

# %% [markdown]
# For our next magic trick, lets navigate to the lovely QMIND website.
#
# This cell will open Chrome, go to the QMIND address, print the title of the site and then close after 5 seconds.
#
# Selenium also provides functions for implicit and explicit waiting, as an alterantive to the time library. These are extremely useful when dealing with stale requests. For this tutorial I am using the time library because it is simpler and there are no actions that suffer from common stale requests.
#
# It is best practice to close the driver instance after every use.

# %%
driver = webdriver.Chrome() # initialize the driver
driver.maximize_window() # Makes the window go full screen
driver.get("https://qmind.ca/") # Opens a new chrome window
print(driver.title)
time.sleep(5)
driver.close()
# Out:
# QMIND – Queens AI Hub

# %% [markdown]
# This can also be done using a "headless" browser, which just means that the browser window won't actually open. Obviously useful for limiting clutter on your computer.

# %%
opts = Options()  
opts.add_argument("--headless") 
driver = webdriver.Chrome(options=opts) # initialize the driver
driver.maximize_window() # Makes the window go full screen
driver.get("https://qmind.ca/") # Opens a new chrome window
print(driver.title) # Grabs the title of the website
driver.close()
# Out:
# QMIND – Queens AI Hub

# %% [markdown]
# Since the QMIND title printed, it is clear that the webdriver worked, it just didn't create a visible window. This is nice so your computer screen does not become cluttered with Selenium windows.
#
# By reading the HTML of any website, you can use Selenium to navigate and extract/enter information. Xpaths are the most versatile way to do this, but there are less complicated ways as well.
# https://www.guru99.com/xpath-selenium.html
#
# In most cases, you will want to use Selenium to input information, becuase other packages often do a better job of scraping, such as BS4.
#
# To find xpaths, simply "inspect" and element and then right click the respective HTML. Select "copy" and then "xpath".
#
# If that doesn't make sense to you just google "How to find the xpath of website elements"

# %% [markdown]
# # Website Interaction
#
# If this code throws an error, it is most likely because the Xpaths have changed on the website. In order to fix this, simply switch the Xpath for username, password and login below.

# %%
driver = webdriver.Chrome() # initialize the driver
driver.maximize_window() # Makes the window go full screen
driver.get("https://twitter.com/login") 

username_xpath = '//*[@id="react-root"]/div/div/div[2]/main/div/div/div[1]/form/div/div[1]/label/div/div[2]/div/input'
password_xpath = '//*[@id="react-root"]/div/div/div[2]/main/div/div/div[1]/form/div/div[2]/label/div/div[2]/div/input'
login_button_xpath = '//*[@id="react-root"]/div/div/div[2]/main/div/div/div[1]/form/div/div[3]/div/div'

username_element = driver.find_element_by_xpath(username_xpath)
password_element = driver.find_element_by_xpath(password_xpath)
login_element = driver.find_element_by_xpath(login_button_xpath)

username_element.send_keys('Placeholder username')
password_element.send_keys('Placeholder password')
time.sleep(2)
login_element.click()

#Can also use Selenium to take screenshots
driver.save_screenshot('screenshot.png')

time.sleep(3)
driver.close()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-6-88d9a459d876> in <module>
#      20
#      21 time.sleep(3)
# ---> 22 driver.close()
#
# ~\anaconda3\envs\MLBase\lib\site-packages\selenium\webdriver\remote\webdriver.py in close(self)
#     686             driver.close()
#     687         """
# --> 688         self.execute(Command.CLOSE)
#     689
#     690     def quit(self):
#
# ~\anaconda3\envs\MLBase\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\envs\MLBase\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=84.0.4147.105)

# %% [markdown]
# Pretty cool. Be careful not to hit websites too frequently as you can get IP banned.
#
# You can also do some "mouse" manipulation using Selenium:
# https://www.pluralsight.com/guides/web-scraping-with-selenium
#
# I have yet to find an instance where this is necesary, but it is really cool.

# %% [markdown]
# # Scraping
#
# Clearly, Selenium is useful in scraping applications where some level of interaction with the website is required. In most cases it is simply better to use BS4 for any scraping needs, while using Selenium to access any parts of the website that require browser interaction.
#
# You can find all elements by a tag such as 'p'.
#
# driver.find_all_elements_by_tag_name('p')
#
# But it is just simpler to use the BS4 parser in my opinion. Below, I scrpae the entire page source from QMIND, which can then be fed into a parser.

# %%
opts = Options()
opts.add_argument('--headless')
opts.add_argument('--incognito')
driver = webdriver.Chrome(options = opts)
driver.maximize_window()

# Grabs the entire page source
driver.get("https://QMIND.ca")
source = driver.page_source
print(source)
# Out:
# <html lang="en-US" data-semplice="5.1.1" class=" "><head>
# 		<meta charset="UTF-8">
# 		<meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0">
# 		<title>QMIND – Queens AI Hub</title>
# <link rel="dns-prefetch" href="//s.w.org">
# 		<script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript">
# 			window._wpemojiSettings = {"baseUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/72x72\/","ext":".png","svgUrl":"https:\/\/s.w.org\/images\/core\/emoji\/13.0.0\/svg\/","svgExt":".svg","source":{"concatemoji":"https:\/\/qmind.ca\/wp-includes\/js\/wp-emoji-release.min.js?ver=5.5"}};
# 			!function(e,a,t){var r,n,o,i,p=a.createElement("canvas"),s=p.getContext&&p.getContext("2d");function c(e,t){var a=String.fromCharCode;s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,e),0,0);var r=p.toDataURL();return s.clearRect(0,0,p.width,p.height),s.fillText(a.apply(this,t),0,0),r===p.toDataURL()}function l(e){if(!s||!s.fillText)return!1;switch(s.textBaseline="top",s.font="600 32px Arial",e){case"flag":return!c([127987,65039,8205,9895,65039],[127987,65039,8203,9895,65039])&&(!c([55356,56826,55356,56819],[55356,56826,8203,55356,56819])&&!c([55356,57332,56128,56423,56128,56418,56128,56421,56128,56430,56128,56423,56128,56447],[55356,57332,8203,56128,56423,8203,56128,56418,8203,56128,56421,8203,56128,56430,8203,56128,56423,8203,56128,56447]));case"emoji":return!c([55357,56424,8205,55356,57212],[55357,56424,8203,55356,57212])}return!1}function d(e){var t=a.createElement("script");t.src=e,t.defer=t.type="text/javascript",a.getElementsByTagName("head")[0].appendChild(t)}for(i=Array("flag","emoji"),t.supports={everything:!0,everythingExceptFlag:!0},o=0;o<i.length;o++)t.supports[i[o]]=l(i[o]),t.supports.everything=t.supports.everything&&t.supports[i[o]],"flag"!==i[o]&&(t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&t.supports[i[o]]);t.supports.everythingExceptFlag=t.supports.everythingExceptFlag&&!t.supports.flag,t.DOMReady=!1,t.readyCallback=function(){t.DOMReady=!0},t.supports.everything||(n=function(){t.readyCallback()},a.addEventListener?(a.addEventListener("DOMContentLoaded",n,!1),e.addEventListener("load",n,!1)):(e.attachEvent("onload",n),a.attachEvent("onreadystatechange",function(){"complete"===a.readyState&&t.readyCallback()})),(r=t.source||{}).concatemoji?d(r.concatemoji):r.wpemoji&&r.twemoji&&(d(r.twemoji),d(r.wpemoji)))}(window,document,window._wpemojiSettings);
# 		</script><script src="https://qmind.ca/wp-includes/js/wp-emoji-release.min.js?ver=5.5" type="text/javascript" defer=""></script>
# 		<style type="text/css">
# img.wp-smiley,
# img.emoji {
# 	display: inline !important;
# 	border: none !important;
# 	box-shadow: none !important;
# 	height: 1em !important;
# 	width: 1em !important;
# 	margin: 0 .07em !important;
# 	vertical-align: -0.1em !important;
# 	background: none !important;
# 	padding: 0 !important;
# }
# </style>
# 	<link rel="stylesheet" id="wp-block-library-css" href="https://qmind.ca/wp-includes/css/dist/block-library/style.min.css?ver=5.5" type="text/css" media="all">
# <link rel="stylesheet" id="semplice-stylesheet-css" href="https://qmind.ca/wp-content/themes/semplice5/style.css?ver=5.1.1" type="text/css" media="all">
# <link rel="stylesheet" id="semplice-frontend-stylesheet-css" href="https://qmind.ca/wp-content/themes/semplice5/assets/css/frontend.min.css?ver=5.1.1" type="text/css" media="all">
# <link rel="stylesheet" id="mediaelement-css" href="https://qmind.ca/wp-includes/js/mediaelement/mediaelementplayer-legacy.min.css?ver=4.2.13-9993131" type="text/css" media="all">
# <script type="text/javascript" src="https://qmind.ca/wp-includes/js/jquery/jquery.js?ver=1.12.4-wp" id="jquery-js"></script>
# <link rel="https://api.w.org/" href="https://qmind.ca/wp-json/"><link rel="alternate" type="application/json" href="https://qmind.ca/wp-json/wp/v2/pages/217"><link rel="EditURI" type="application/rsd+xml" title="RSD" href="https://qmind.ca/xmlrpc.php?rsd">
# <link rel="wlwmanifest" type="application/wlwmanifest+xml" href="https://qmind.ca/wp-includes/wlwmanifest.xml">
# <meta name="generator" content="WordPress 5.5">
# <link rel="canonical" href="https://qmind.ca/">
# <link rel="shortlink" href="https://qmind.ca/">
# <link rel="alternate" type="application/json+oembed" href="https://qmind.ca/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fqmind.ca%2F">
# <link rel="alternate" type="text/xml+oembed" href="https://qmind.ca/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fqmind.ca%2F&amp;format=xml">
# <link href="https://fonts.googleapis.com/css?family=Roboto+Mono:400,400i,500,500i&amp;display=swap" rel="stylesheet"><style type="text/css" id="semplice-webfonts-selfhosted">@font-face {
#   font-family: 'Inter-Thin-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-ThinItalic-BETA.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-ExtraLight';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-ExtraLight-BETA.woff') format('woff');
# }
# @font-face {
#   font-family: 'Inter-ExtraLight-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-ExtraLightItalic-BETA.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-Light';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-Light-BETA.woff') format('woff');
# }
# @font-face {
#   font-family: 'Inter-Light-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-LightItalic-BETA.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-Regular';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-Regular.woff') format('woff')
# }
#
# @font-face {
#   font-family: 'Inter-Regular-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-Italic.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-Medium';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-Medium.woff') format('woff')；
# }
# @font-face {
#   font-family: 'Inter-Medium-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-MediumItalic.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-SemiBold';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-SemiBold.woff') format('woff')
# }
# @font-face {
#   font-family: 'Inter-SemiBold-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-SemiBoldItalic.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-Bold';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-Bold.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-Bold-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-BoldItalic.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-ExtraBold';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-ExtraBold.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-ExtraBold-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-ExtraBoldItalic.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-Black';
#   font-style:  normal;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-Black.woff') format('woff');
# }
#
# @font-face {
#   font-family: 'Inter-Black-Italic';
#   font-style:  italic;
#   font-display: swap;
#   src: url('https://qmind.ca/wp-content/uploads/2020/04/Inter-BlackItalic.woff') format('woff');
# }</style><style type="text/css" id="semplice-webfonts-css">.font_4bec2ju5t, [data-font="font_4bec2ju5t"], [data-font="font_4bec2ju5t"] li a {font-family: "Inter-Black", sans-serif;font-weight: normal;font-style: normal;}.font_hcilocsgy, [data-font="font_hcilocsgy"], [data-font="font_hcilocsgy"] li a {font-family: "Inter-BlackItalic", sans-serif;font-weight: normal;font-style: normal;}.font_eh55de4iy, [data-font="font_eh55de4iy"], [data-font="font_eh55de4iy"] li a {font-family: "Inter-ExtraBold", sans-serif;font-weight: normal;font-style: normal;}.font_pypem4ubt, [data-font="font_pypem4ubt"], [data-font="font_pypem4ubt"] li a {font-family: "Inter-ExtraBoldItalic", sans-serif;font-weight: normal;font-style: normal;}.font_2vpfjqzui, [data-font="font_2vpfjqzui"], [data-font="font_2vpfjqzui"] li a, #content-holder h1, #content-holder h2 {font-family: "Inter-Bold", sans-serif;font-weight: normal;font-style: normal;}.font_6lslw579o, [data-font="font_6lslw579o"], [data-font="font_6lslw579o"] li a {font-family: "Inter-BoldItalic", sans-serif;font-weight: normal;font-style: normal;}.font_nzyq6zth3, [data-font="font_nzyq6zth3"], [data-font="font_nzyq6zth3"] li a, #content-holder h3 {font-family: "Inter-SemiBold", sans-serif;font-weight: normal;font-style: normal;}.font_xt58ts3s1, [data-font="font_xt58ts3s1"], [data-font="font_xt58ts3s1"] li a {font-family: "Inter-SemiBoldItalic", sans-serif;font-weight: 400;font-style: normal;}.font_s1cuq8sto, [data-font="font_s1cuq8sto"], [data-font="font_s1cuq8sto"] li a {font-family: "Inter-Medium", sans-serif;font-weight: normal;font-style: normal;}.font_4vx15s73u, [data-font="font_4vx15s73u"], [data-font="font_4vx15s73u"] li a {font-family: "Inter-MediumItalic", sans-serif;font-weight: normal;font-style: normal;}.font_l8n6lam2f, [data-font="font_l8n6lam2f"], [data-font="font_l8n6lam2f"] li a, #content-holder p, #content-holder li {font-family: "Inter-Regular", sans-serif;font-weight: normal;font-style: normal;}.font_72z1lw4w4, [data-font="font_72z1lw4w4"], [data-font="font_72z1lw4w4"] li a {font-family: "Inter-Italic", sans-serif;font-weight: normal;font-style: normal;}.font_izyyaqykr, [data-font="font_izyyaqykr"], [data-font="font_izyyaqykr"] li a {font-family: "Roboto Mono", sans-serif;font-weight: 400;font-style: normal;}.font_kxu7cufdo, [data-font="font_kxu7cufdo"], [data-font="font_kxu7cufdo"] li a {font-family: "Roboto Mono", sans-serif;font-weight: 400;font-style: italic;}.font_e5buslk7l, [data-font="font_e5buslk7l"], [data-font="font_e5buslk7l"] li a {font-family: "Roboto Mono", sans-serif;font-weight: 500;font-style: normal;}.font_8qha1n2hl, [data-font="font_8qha1n2hl"], [data-font="font_8qha1n2hl"] li a {font-family: "Roboto Mono", sans-serif;font-weight: 500;font-style: italic;}</style>
# 		<style type="text/css" id="semplice-custom-css">
#
# 				@media screen and (min-width: 1170px) {
# 					.container-fluid, .container, .admin-container {
# 						padding: 0 7.77778rem 0 7.77778rem;
# 					}
# 				}
# 			.container {
# 			max-width: 1580px;
# 		}@media screen and (max-width: 1169px) { .row {
# 			margin-left: -12px;
# 			margin-right: -12px;
# 		}.column, .grid-column {
# 			padding-left: 12px;
# 			padding-right: 12px;
# 		}}@media screen and (min-width: 1170px) { .row {
# 			margin-left: -15px;
# 			margin-right: -15px;
# 		}.column, .grid-column {
# 			padding-left: 15px;
# 			padding-right: 15px;
# 		}}
# 			#content-holder h1 { font-size: 2.7777777777777777rem;line-height: 3.111111111111111rem;letter-spacing: -0.011111111111111112rem;}#content-holder h2 { font-size: 2.2222222222222223rem;line-height: 2.6666666666666665rem;letter-spacing: -0.022222222222222223rem;}#content-holder h3 { font-size: 1.3333333333333333rem;line-height: 1.6666666666666667rem;letter-spacing: -0.022222222222222223rem;}#content-holder p, #content-holder li { font-size: 0.8888888888888888rem;line-height: 1.6666666666667;letter-spacing: -0.005555555555555556rem;}#content-holder .is-content p { margin-bottom: 1.6666666666667em; }@media screen and (min-width: 992px) and (max-width: 1169.98px) { }@media screen and (min-width: 768px) and (max-width: 991.98px) { }@media screen and (min-width: 544px) and (max-width: 767.98px) { }@media screen and (max-width: 543.98px) { }
#
#
# 		.project-panel {
# 			background: #f5f5f5;
# 			padding: 2.5rem 0rem;
# 		}
# 		[data-pp-gutter="no"] .project-panel .pp-thumbs,
# 		.project-panel .pp-thumbs {
# 			margin-bottom: -1.666666666666667rem;
# 		}
# 		#content-holder .panel-label, .projectnav-preview .panel-label {
# 			color: #000000;
# 			font-size: 1.777777777777778rem;
# 			text-transform: none;
# 			padding-left: 0rem;
# 			padding-bottom: 1.666666666666667rem;
# 			text-align: left;
# 			line-height: 1;
# 		}
# 		.project-panel .pp-title {
# 			padding: 0.5555555555555556rem 0rem 1.666666666666667rem 0rem;
# 		}
# 		.project-panel .pp-title a {
# 			color: #000000;
# 			font-size: 0.7222222222222222rem;
# 			text-transform: none;
# 		}
# 		.project-panel .pp-title span {
# 			color: #999999;
# 			font-size: 0.7222222222222222rem;
# 			text-transform: none;
# 		}
# 		.semplice-next-prev {
# 			background: #ffffff;
# 			padding: 0rem 0rem 0rem 0rem;
# 		}
# 		.semplice-next-prev .np-inner {
# 			height: 10rem;
# 		}
# 		.semplice-next-prev .np-inner .np-link .np-prefix,
# 		.semplice-next-prev .np-inner .np-link .np-label {
# 			color: #000000;
# 			font-size: 1.555555555555556rem;
# 			text-transform: none;
# 			letter-spacing: 0rem;
# 		}
# 		.semplice-next-prev .np-inner .np-link .np-text-above {
# 			padding-bottom: 2px;
# 		}
# 		.semplice-next-prev .np-inner .np-link .np-label-above {
# 			color: #aaaaaa;
# 			font-size: 0.7777777777777778rem;
# 			text-transform: uppercase;
# 			letter-spacing: 1px;
# 		}
# 		.semplice-next-prev .np-inner .np-link .np-text {
# 			padding: 0rem 0rem;
# 		}
# 		.semplice-next .np-text {
# 			margin-right: -0rem;
# 		}
# 		.semplice-next-prev .nextprev-seperator {
# 			width: 1px;
# 			margin: 1.666666666666667rem -0px;
# 			background: #000000;
# 		}
#
# 			.np-link:hover {
# 				background: #ffffff;
# 			}
# 			.np-link:hover .np-text .np-label,
# 			.np-link:hover .np-text .np-prefix {
# 				color: #000000 !important;
# 			}
# 			.np-link:hover .np-label-above {
# 				color: #000000 !important;
# 			}
#
# 			a { color: #2b69e7; }a:hover { color: #2b69e7; }.underline-links a {position: relative; display: inline-block;}
# .underline-links a:before {
#     content: '';
#     position: absolute;
#     z-index: 0;
#     left: 0;
#     right: 100%;
#     bottom: 0;
#     background: #2B69E7;
#     height: 2px;
#     -webkit-transition-property: right;
#     transition-property: right;
#     -webkit-transition-duration: 0.2s;
#     transition-duration: 0.2s;
#     -webkit-transition-timing-function: ease-out;
#     transition-timing-function: ease-out;
# }
#
# .underline-links a:hover:before {right: 0 !important;}
# .underline-links a:hover {
# 	color: #2B69E7;
# }@media screen and (min-width: 1170px){.hide-for-desktop-wide {display: none !important}}@media screen and (min-width: 992px) and (max-width: 1169.98px){.hide-for-desktop {display: none !important}}@media screen and (min-width: 768px) and (max-width: 991.98px){ .hide-for-tablet-wide {display: none !important}}@media screen and (min-width: 544px) and (max-width: 767.98px){ .hide-for-tablet-portrait {display: none !important}}@media screen and (max-width: 543.98px){ .hide-for-mobile {display: none !important}}
# 		</style>
#
# 		<style type="text/css" id="217-post-css">
# 			#content-217 #content_669d7970d {padding-top: 7.222222222222222rem;padding-bottom: 10rem;}#content-217 #content_669d7970d .is-content {}#content-217 #section_22fe9d332 {padding-top: 1.3888888888888888rem;margin-top: 0rem;padding-right: 0rem;padding-bottom: 3.888888888888889rem;background-color: #f7f7f7;}#content-217 #content_018aec787 {padding-top: 0rem;margin-top: -3.6666666666666665rem;margin-right: 0rem;padding-bottom: 0rem;margin-bottom: 0rem;}#content-217 #content_018aec787 .is-content {}#content-217 #content_5be69b046 {padding-top: 0rem;margin-top: 1.4444444444444444rem;padding-right: 2.3333333333333335rem;margin-right: 0rem;margin-left: 0rem;}#content-217 #content_5be69b046 .is-content {}#content-217 #content_2kl4qhxo2 .spacer { background-color: transparent; }#content-217 #content_2kl4qhxo2 .spacer { height: 6.5rem; }#content-217 #column_a5d683d74 {padding-top: 0rem;}#content-217 #content_2ef556c83 {padding-top: 1.4444444444444444rem;margin-top: 0rem;margin-left: -2.7777777777777777rem;}#content-217 #content_2ef556c83 .is-content {}@media screen and (min-width: 544px) and (max-width: 767.98px) { #content-217 #content_2ef556c83 {margin-left: 0rem;}#content-217 #content_2ef556c83 .is-content {}}@media screen and (max-width: 543.98px) { #content-217 #content_2ef556c83 {margin-left: 0rem;}#content-217 #content_2ef556c83 .is-content {}}#content-217 #content_ceada92a9 {padding-top: 0.2777777777777778rem;margin-top: 0rem;margin-right: 0rem;margin-left: -2.7777777777777777rem;}#content-217 #content_ceada92a9 .is-content {}@media screen and (min-width: 544px) and (max-width: 767.98px) { #content-217 #content_ceada92a9 {margin-left: 0rem;}#content-217 #content_ceada92a9 .is-content {}}@media screen and (max-width: 543.98px) { #content-217 #content_ceada92a9 {margin-left: 0rem;}#content-217 #content_ceada92a9 .is-content {}}#content-217 #content_c6d5j5zdn .spacer { background-color: transparent; }#content-217 #content_c6d5j5zdn .spacer { height: 6.5rem; }#content-217 #column_63d203ae3 {padding-top: 0rem;padding-bottom: 0rem;}#content-217 #content_a8299d3b9 {padding-top: 0rem;margin-top: -4.888888888888889rem;padding-bottom: 0rem;margin-bottom: 0rem;margin-left: 0rem;}#content-217 #content_a8299d3b9 .is-content {}#content-217 #content_23ef22194 {margin-top: -4.888888888888889rem;margin-left: 0rem;}#content-217 #content_23ef22194 .is-content {}#content-217 #section_95f0c7b49 {padding-top: 5.555555555555555rem;padding-bottom: 3.3333333333333335rem;}#content-217 #content_jwddrrc4o {padding-bottom: 0.7777777777777778rem;}#content-217 #content_jwddrrc4o .is-content {}#content-217 #content_pdni1gtel {padding-bottom: 0.7777777777777778rem;}#content-217 #content_pdni1gtel .is-content {}#content-217 #content_sjorq7reg {padding-bottom: 0.7777777777777778rem;}#content-217 #content_sjorq7reg .is-content {}#content-217 #content_xm00jcqpa {padding-bottom: 0.7777777777777778rem;}#content-217 #content_xm00jcqpa .is-content {}#content-217 #content_72bl8qgk8 .spacer { background-color: transparent; }#content-217 #content_72bl8qgk8 .spacer { height: 4.444444444444445rem; }#content-217 #section_00a80da83 {background-color: #d8d8d8;}#content-217 #content_819f4d3c0 .spacer { background-color: #d8d8d8; }#content-217 #content_819f4d3c0 .spacer { height: 0.05555555555555555rem; }#content-217 #content_abf2ccba7 {padding-top: 3.3333333333333335rem;padding-bottom: 0rem;}#content-217 #content_abf2ccba7 .is-content {}#content-217 #content_3e83cb232 {padding-top: 2.111111111111111rem;}#content-217 #content_3e83cb232 .is-content {}#content-217 #content_25fc91f0c {padding-top: 3.3333333333333335rem;padding-right: 0rem;}#content-217 #content_25fc91f0c .is-content {}#content-217 .thumb .thumb-inner .thumb-hover {background-color: rgba(0, 0, 0, 0.05);background-size: auto;background-position: 0% 0%;background-repeat: no-repeat;}.is-frontend #content-217 .thumb .thumb-inner { transition: box-shadow 0.3s ease; }.is-frontend #content-217 .thumb .thumb-inner:hover, . ...
# 					#content-217 #content_190250f26 .thumb .post-title {
# 						padding-top: 0rem;padding-left: 1.1111111111111112rem;padding-bottom: 1.1111111111111112rem;padding-right: 0rem;
# 					}
# 					#content_190250f26 .thumb .post-title,
# 					#content_190250f26 .thumb .post-title a {
# 						color: #ffffff;
# 						font-size: 1rem;
# 						text-transform: none;
# 					}
# 					#content_190250f26 .thumb .post-title span,
# 					#content_190250f26 .thumb .post-title a span {
# 						color: #ffffff;
# 						font-size: 0.7777777777777778rem;
# 						text-transform: none;
# 						padding-top: 0.7222222222222222rem;
# 					}
# 					#content-217 #content_190250f26 nav ul li a {
# 						color: #bbbbbb;
# 						text-transform: none;
# 					}
# 					#content-217 #content_190250f26 nav ul li a:hover,
# 					#content-217 #content_190250f26 nav ul li a.pg-filter-active {
# 						color: #000000;
# 						text-decoration: none;
# 					}
# 				#content-217 #content_190250f26 {padding-top: 2.7777777777777777rem;}#content-217 #content_190250f26 .is-content {}#content-217 #section_11c2157c7 {padding-bottom: 4.444444444444445rem;}
# 				#content-217 #content_iy3qxayno .is-content {border-width: 0.05555555555555555rem;border-color: #2b69e7;background-color: transparent;}
# 				#content-217 #content_iy3qxayno .is-content:hover {background-color: #daeaff !important;color: #2b69e7 !important;}
# 				#content-217 #content_iy3qxayno .is-content a{color: #2b69e7;}
# 				#content-217 #content_iy3qxayno .is-content:hover a {color: #2b69e7 !important;}
# 			#content-217 #content_iy3qxayno {padding-top: 3.3333333333333335rem;}#content-217 #content_iy3qxayno .is-content {}
# 				#content-217 #content_bwsumzz81 .is-content {border-width: 0.05555555555555555rem;border-color: #2b69e7;background-color: transparent;}
# 				#content-217 #content_bwsumzz81 .is-content:hover {background-color: #2b69e7 !important;color: #ffffff !important;}
# 				#content-217 #content_bwsumzz81 .is-content a{color: #ffffff;}
# 				#content-217 #content_bwsumzz81 .is-content:hover a {color: #ffffff !important;}
# 			#content-217 #content_bwsumzz81 {padding-top: 0rem;margin-top: 3.3333333333333335rem;background-color: #2b69e7;}#content-217 #content_bwsumzz81 .is-content {}#content-217 #section_e5dd0c3b8 {background-color: #d8d8d8;}#content-217 #content_630fa8898 .spacer { background-color: #d8d8d8; }#content-217 #content_630fa8898 .spacer { height: 0.05555555555555555rem; }#content-217 #content_4522d91c3 {padding-top: 3.3333333333333335rem;padding-bottom: 0rem;}#content-217 #content_4522d91c3 .is-content {}#content-217 #content_d76184867 {padding-top: 2.111111111111111rem;}#content-217 #content_d76184867 .is-content {}#content-217 #content_e90496b24 {padding-top: 3.3333333333333335rem;padding-right: 0rem;}#content-217 #content_e90496b24 .is-content {}#content-217 #section_504625fb9 {padding-bottom: 4.444444444444445rem;}
# 				#content-217 #content_6de248876 .is-content {border-width: 0.05555555555555555rem;border-color: #2b69e7;background-color: transparent;}
# 				#content-217 #content_6de248876 .is-content:hover {background-color: #daeaff !important;color: #2b69e7 !important;}
# 				#content-217 #content_6de248876 .is-content a{color: #2b69e7;}
# 				#content-217 #content_6de248876 .is-content:hover a {color: #2b69e7 !important;}
# 			#content-217 #content_6de248876 {padding-top: 3.3333333333333335rem;}#content-217 #content_6de248876 .is-content {}
# 				#content-217 #content_d9e585799 .is-content {border-width: 0.05555555555555555rem;border-color: #2b69e7;background-color: transparent;}
# 				#content-217 #content_d9e585799 .is-content:hover {background-color: #2b69e7 !important;color: #ffffff !important;}
# 				#content-217 #content_d9e585799 .is-content a{color: #ffffff;}
# 				#content-217 #content_d9e585799 .is-content:hover a {color: #ffffff !important;}
# 			#content-217 #content_d9e585799 {padding-top: 0rem;margin-top: 3.3333333333333335rem;background-color: #2b69e7;}#content-217 #content_d9e585799 .is-content {}#content-217 #section_bb6894fb1 {background-color: #d8d8d8;}#content-217 #content_daac58c5d .spacer { background-color: #d8d8d8; }#content-217 #content_daac58c5d .spacer { height: 0.05555555555555555rem; }#content-217 #content_d17bac26c {padding-top: 3.3333333333333335rem;padding-bottom: 0rem;}#content-217 #content_d17bac26c .is-content {}#content-217 #content_abcd1ffc8 {padding-top: 2.111111111111111rem;}#content-217 #content_abcd1ffc8 .is-content {}#content-217 #content_da5b8099a {padding-top: 3.3333333333333335rem;padding-right: 0rem;padding-bottom: 0.6666666666666666rem;}#content-217 #content_da5b8099a .is-content {}#content-217 #content_ev6aziqmy .spacer { background-color: transparent; }#content-217 #content_ev6aziqmy .spacer { height: 1.1111111111111112rem; }#content-217 #content_hmdq1h2z4 {padding-top: 0.2777777777777778rem;}#content-217 #content_hmdq1h2z4 .is-content {}#content-217 #content_p2ng9yn8y {padding-top: 0.2777777777777778rem;}#content-217 #content_p2ng9yn8y .is-content {}#content-217 #content_bm26vcfw6 {padding-top: 0.2777777777777778rem;}#content-217 #content_bm26vcfw6 .is-content {}#content-217 #section_a8630d612 {padding-bottom: 4.444444444444445rem;}#content-217 #section_66d119b26 {background-color: #d8d8d8;}#content-217 #column_de9c28376 {background-color: transparent;}#content-217 #content_54f358e80 .spacer { background-color: #d8d8d8; }#content-217 #content_54f358e80 .spacer { height: 0.05555555555555555rem; }#content-217 #content_fa3a4f035 {padding-top: 3.3333333333333335rem;padding-bottom: 0rem;}#content-217 #content_fa3a4f035 .is-content {}#content-217 #content_1bec46198 {padding-top: 2.111111111111111rem;}#content-217 #content_1bec46198 .is-content {}#content-217 #content_a9a3876e7 {padding-top: 3.3333333333333335rem;padding-right: 0rem;padding-bottom: 3.3333333333333335rem;}#content-217 #content_a9a3876e7 .is-content {}#content-217 #section_1rquskc0m .container {height: 25rem;}@media screen and (max-width: 543.98px) { #content-217 #section_1rquskc0m {margin-top: 0rem;}}
# 					#content_412926f7e .flickity-prev-next-button .arrow { fill: #ffffff !important; }
# 					#content_412926f7e .flickity-page-dots .dot { background: #000000 !important; }
# 					#content_412926f7e .flickity-meta .flickity-caption { color: #000000; font-size: 0.8888888888888889rem; text-transform: none; }
# 					#content_412926f7e .flickity-button-icon path { fill: #ffffff; }
# 					#content_412926f7e .flickity-prev-next-button { background-color: rgba(0, 0, 0, 0); }
# 					#section_1rquskc0m .row, #section_1rquskc0m .row .column { min-height: 100% !important; } #section_1rquskc0m .column-content { height: 25rem; }#content-217 #content_412926f7e {padding-top: 0rem;margin-top: 0rem;padding-right: 0rem;padding-bottom: 0rem;padding-left: 0rem;}#content-217 #content_412926f7e .is-content {border-radius: 0rem;border-color: transparent;}#content-217 #section_5e9f7dd34 {padding-bottom: 5.555555555555555rem;}#content-217 #section_a815ff4aa {background-color: #d8d8d8;}#content-217 #content_2243e821f .spacer { background-color: #d8d8d8; }#content-217 #content_2243e821f .spacer { height: 0.05555555555555555rem; }#content-217 #content_ddbd7fd07 {padding-top: 3.3333333333333335rem;padding-bottom: 0rem;}#content-217 #content_ddbd7fd07 .is-content {}#content-217 #content_251736b42 {padding-top: 2.111111111111111rem;}#content-217 #content_251736b42 .is-content {}#content-217 #content_ec98ef3a0 {padding-top: 3.3333333333333335rem;padding-right: 0rem;padding-bottom: 3.3333333333333335rem;}#content-217 #content_ec98ef3a0 .is-content {}#content-217 #content_kgwlvec83 {padding-bottom: 3.3333333333333335rem;}#content-217 #content_kgwlvec83 .is-content {}#content-217 #content_zsi1tng5g {padding-bottom: 3.3333333333333335rem;z-index: 2;}#content-217 #content_zsi1tng5g .is-content {}#content-217 #content_1t8f6ipzk {padding-bottom: 3.3333333333333335rem;}#content-217 #content_1t8f6ipzk .is-content {}#content-217 #content_afo2ey7w9 {padding-bottom: 1.1111111111111112rem;}#content-217 #content_afo2ey7w9 .is-content {}
# 					#content_lu3dvi5hc .flickity-prev-next-button .arrow { fill: #ffffff !important; }
# 					#content_lu3dvi5hc .flickity-page-dots .dot { background: #a2a4ab !important; }
# 					#content_lu3dvi5hc .flickity-meta .flickity-caption { color: #000000; font-size: 0.8888888888888889rem; text-transform: none; }
# 					#content_lu3dvi5hc .flickity-button-icon path { fill: #ffffff; }
# 					#content_lu3dvi5hc .flickity-prev-next-button { background-color: rgba(0, 0, 0, 0); }
# 					#content-217 #content_lu3dvi5hc {padding-bottom: 3.3333333333333335rem;}#content-217 #content_lu3dvi5hc .is-content {}#content-217 #section_96f1d48a5 {padding-bottom: 4.444444444444445rem;}
# 				#content-217 #content_760f6d4de .is-content {border-width: 0.05555555555555555rem;border-color: #fad522;background-color: transparent;}
# 				#content-217 #content_760f6d4de .is-content:hover {background-color: #f6d048 !important;color: #020202 !important;}
# 				#content-217 #content_760f6d4de .is-content a{color: #020202;}
# 				#content-217 #content_760f6d4de .is-content:hover a {color: #ffffff !important;}
# 			#content-217 #content_760f6d4de {padding-top: 0rem;margin-top: 0rem;background-color: #fad522;}#content-217 #content_760f6d4de .is-content {}#content-217 #section_uophjh8pt {background-color: #d8d8d8;}#content-217 #content_aqm566ehv .spacer { background-color: #d8d8d8; }#content-217 #content_aqm566ehv .spacer { height: 0.05555555555555555rem; }#content-217 #content_z18ik88pz {padding-top: 3.3333333333333335rem;padding-bottom: 0rem;}#content-217 #content_z18ik88pz .is-content {}#content-217 #content_vc9lu5sg9 {padding-top: 2.111111111111111rem;}#content-217 #content_vc9lu5sg9 .is-content {}#content-217 #content_2kzkoac3z {padding-top: 3.3333333333333335rem;padding-right: 0rem;padding-bottom: 3.3333333333333335rem;}#content-217 #content_2kzkoac3z .is-content {}#content-217 #content_2zsu4a0qx {padding-bottom: 1.6666666666666667rem;}#content-217 #content_2zsu4a0qx .is-content {}#content-217 #content_cpchsf6zw .spacer { background-color: transparent; }#content-217 #content_cpchsf6zw .spacer { height: 5rem; }#content-217 #section_867ab04a5 {padding-top: 5.555555555555555rem;padding-bottom: 6.666666666666667rem;background-color: #f7f7f7;}#content-217 #content_94b12464f {padding-bottom: 2.111111111111111rem;}#content-217 #content_94b12464f .is-content {}#content-217 #content_830b3f299 {padding-bottom: 1.3333333333333333rem;}#content-217 #content_830b3f299 .is-content {}#content-217 #content_a88879577 {padding-bottom: 0.4444444444444444rem;}#content-217 #content_a88879577 .is-content {}#content-217 #content_2c162d8f6 {padding-bottom: 1.3333333333333333rem;}#content-217 #content_2c162d8f6 .is-content {}#content-217 #content_6ad375b71 {padding-bottom: 0.4444444444444444rem;}#content-217 #content_6ad375b71 .is-content {}#content-217 #content_4f3f766cf {padding-bottom: 1.3333333333333333rem;}#content-217 #content_4f3f766cf .is-content {}#content-217 #content_b66db8180 {padding-bottom: 0.4444444444444444rem;}#content-217 #content_b66db8180 .is-content {}#content-217 #content_0g8uvjegq {padding-bottom: 0.4444444444444444rem;}#content-217 #content_0g8uvjegq .is-content {}#content-217 #content_6c448cd22 {padding-bottom: 0.4444444444444444rem;}#content-217 #content_6c448cd22 .is-content {}#content-217 #content_ed7b866cb {padding-bottom: 0.4444444444444444rem;}#content-217 #content_ed7b866cb .is-content {}#content-217 #content_bo4j5oyvx {padding-bottom: 0.4444444444444444rem;}#content-217 #content_bo4j5oyvx .is-content {}#content-217 .transition-wrap {}#content-217 #section_6f3dbed49 {padding-top: 2.7777777777777777rem;padding-bottom: 2.7777777777777777rem;background-color: #161616;}
# 			.nav_ruothfxma { background-color: transparent;; }.nav_ruothfxma { height: 5.555555555555555rem; }.is-frontend #content-217 .sections { margin-top: 5.555555555555555rem; }.nav_ruothfxma .logo img, .nav_ruothfxma .logo svg { width: 5.555555555555555rem; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon span { background-color: #000000; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon { width: 1.3333333333333333rem; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon span { height: 2px; }.nav_ruothfxma .navbar-inner .hamburger a.open-menu span::before { transform: translateY(-6px); }.nav_ruothfxma .navbar-inner .hamburger a.open-menu span::after { transform: translateY(6px); }.nav_ruothfxma .navbar-inner .hamburger a.open-menu:hover span::before { transform: translateY(-8px); }.nav_ruothfxma .navbar-inner .hamburger a.open-menu:hover span::after { transform: translateY(8px); }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon { height: 14px; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon span { margin-top: 7px; }.nav_ruothfxma .navbar-inner nav ul li a span { font-size: 0.8888888888888888rem; }.nav_ruothfxma .navbar-inner nav ul li a span { letter-spacing: -0.016666666666666666rem; }.nav_ruothfxma .navbar-inner nav ul li a:hover span, .navbar-inner nav ul li.current-menu-item a span, .navbar-inner nav ul li.current_page_item a span, .nav_ruothfxma .navbar-inner nav ul li.wrap-focus a span { color: #2b69e7; }.nav_ruothfxma .navbar-inner nav ul li.current-menu-item a span { color: #2b69e7; }.nav_ruothfxma .navbar-inner nav ul li.current_page_item a span { color: #2b69e7; }[data-post-type="project"] .navbar-inner nav ul li.portfolio-grid a span, [data-post-type="post"] .navbar-inner nav ul li.blog-overview a span { color: #2b69e7; }#overlay-menu { background-color: rgba(255, 255, 255, 1); }#overlay-menu .overlay-menu-inner nav ul li a span { font-size: 1.1111111111111112rem; }#overlay-menu .overlay-menu-inner nav ul li a { padding-top: 0.55555555555556rem; }#overlay-menu .overlay-menu-inner nav ul li a { padding-bottom: 0.55555555555556rem; }#overlay-menu .overlay-menu-inner nav ul li a span { text-transform: none; }#overlay-menu .overlay-menu-inner nav ul li a:hover span { color: #2b69e7; }#overlay-menu .overlay-menu-inner nav ul li.current-menu-item a span { color: #2b69e7; }#overlay-menu .overlay-menu-inner nav ul li.current_page_item a span { color: #2b69e7; }[data-post-type="project"] #overlay-menu .overlay-menu-inner nav ul li.portfolio-grid a span, [data-post-type="post"] #overlay-menu .overlay-menu-inner nav ul li.blog-overview a span { color: #2b69e7; }@media screen and (min-width: 992px) and (max-width: 1169.98px) { .nav_ruothfxma .navbar-inner .hamburger a.menu-icon { height: 14px; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon span { margin-top: 7px; }}@media screen and (min-width: 768px) and (max-width: 991.98px) { .nav_ruothfxma .navbar-inner .hamburger a.menu-icon { height: 14px; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon span { margin-top: 7px; }}@media screen and (min-width: 544px) and (max-width: 767.98px) { .nav_ruothfxma .navbar-inner .hamburger a.menu-icon { height: 14px; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon span { margin-top: 7px; }}@media screen and (max-width: 543.98px) { .nav_ruothfxma .navbar-inner .hamburger a.menu-icon { height: 14px; }.nav_ruothfxma .navbar-inner .hamburger a.menu-icon span { margin-top: 7px; }}
# 		</style>
# 	<link rel="icon" href="https://qmind.ca/wp-content/uploads/2020/04/cropped-New-QMIND-Logo-32x32.png" sizes="32x32">
# <link rel="icon" href="https://qmind.ca/wp-content/uploads/2020/04/cropped-New-QMIND-Logo-192x192.png" sizes="192x192">
# <link rel="apple-touch-icon" href="https://qmind.ca/wp-content/uploads/2020/04/cropped-New-QMIND-Logo-180x180.png">
# <meta name="msapplication-TileImage" content="https://qmind.ca/wp-content/uploads/2020/04/cropped-New-QMIND-Logo-270x270.png">
# 		<style>html{margin-top:0px!important;}#wpadminbar{top:auto!important;bottom:0;}</style>
# 		<script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-164507294-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-164507294-1');
# </script>
# <link rel="shortcut icon" type="image/png" href="https://qmind.ca/wp-content/uploads/2020/04/New-QMIND-Logo.png" sizes="32x32">	<style id="content_190250f26-style" type="text/css">#masonry-content_190250f26{ margin: auto -6px !important; } .masonry-content_190250f26-item { margin: 0px; padding-left: 6px; padding-right: 6px; padding-bottom: 30px; }</style></head>
# 	<body class="home page-template-default page page-id-217 is-frontend dynamic-mode mejs-semplice-ui elementor-default" data-post-type="page" data-post-id="217" data-breakpoint-js="md">
# 		<div id="content-holder" data-active-post="217">
#
#
#
#
#
#
# 			<div id="content-217" class="content-container active-content"><header class="nav_ruothfxma semplice-navbar active-navbar non-sticky-nav  cover-transparent" data-cover-transparent="enabled" data-bg-overlay-visibility="hidden" data-mobile-fallback="enabled" style="opacity: 1; transform: none;">
# 							<div class="container" data-nav="logo-left-menu-right">
# 								<div class="navbar-inner menu-type-text" data-xl-width="12" data-navbar-type="container">
# 									<div class="logo navbar-left"><a href="https://qmind.ca" title="QMIND"><img src="https://qmind.ca/wp-content/uploads/2020/04/logo_text@1x.png" alt="logo"></a></div>
# 									<nav class="standard navbar-right" data-font="font_l8n6lam2f"><ul class="menu"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-179"><a href="#design"><span>Design</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-180"><a href="#research"><span>Research</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-182"><a href="#educate"><span>Educate</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-183"><a href="#events"><span>Events</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-181"><a href="#partnership"><span>Partnerships</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-271"><a href="#more"><span>More</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-184"><a href="#get-in-touch"><span>→ Get in touch</span></a></li>
# </ul></nav>
# 									<div class="hamburger navbar-right semplice-menu"><a class="open-menu menu-icon"><span></span></a></div>
# 								</div>
# 							</div>
# 						</header><div id="overlay-menu">
# 					<div class="overlay-menu-inner" data-xl-width="12">
# 						<nav class="overlay-nav" data-justify="center" data-align="align-middle" data-font="font_nzyq6zth3">
# 							<ul class="container"><li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-179"><a href="#design"><span>Design</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-180"><a href="#research"><span>Research</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-182"><a href="#educate"><span>Educate</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-183"><a href="#events"><span>Events</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-181"><a href="#partnership"><span>Partnerships</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-271"><a href="#more"><span>More</span></a></li>
# <li class="menu-item menu-item-type-custom menu-item-object-custom menu-item-184"><a href="#get-in-touch"><span>→ Get in touch</span></a></li>
# </ul>
# 						</nav>
# 					</div>
# 				</div>
# 				<div class="transition-wrap">
# 					<div class="sections">
#
# 					<section id="section_307c3d0ad" class="content-block reveal" data-column-mode-sm="single" data-column-mode-xs="single" data-sr-id="1" style="; visibility: visible;  -webkit-transform: translateY(0) scale(1); opacity: 1;transform: translateY(0) scale(1); opacity: 1;-webkit-transition: -webkit-transform 0.7s ease-in-out 0s, opacity 0.7s ease-in-out 0s; transition: transform 0.7s ease-in-out 0s, opacity 0.7s ease-in-out 0s; ">
# 						<div class="container"><div id="row_c740316ee" class="row"><div id="column_f68783954" class="column" data-xl-width="12">
# 					<div class="content-wrapper">
#
# 				<div id="content_669d7970d" class="column-content" data-module="text">
# 					<div class="is-content"><h1 style="text-align: center; line-height: 3.389rem;" data-mce-style="text-align: center; line-height: 3.389rem;" data-line-height-xl="3.389rem"><strong>Empowering future leaders to unlock the full potential of AI</strong></h1></div>
# 				</div>
#
# 					</div>
# 				</div></div></div>
# 					</section>
#
# 					<section id="section_22fe9d332" class="content-block reveal" data-column-mode-sm="single" data-column-mode-xs="single" data-xs-visibility="visbile" data-sr-id="2" style="; visibility: visible;  -webkit-transform: translateY(5px) scale(1); opacity: 0;transform: translateY(5px) scale(1); opacity: 0;">
# 						<div class="container"><div id="row_c0e48e27a" class="row"><div id="column_8b029ef8f" class="column hide-for-mobile" data-xl-width="3" data-md-width="3" data-lg-width="3">
# 					<div class="content-wrapper">
#
# 				<div id="content_018aec787" class="column-content hide-for-mobile hide-for-tablet-portrait" data-module="image">
# 					<div class="ce-image" data-align="left"><img class="is-content" src="https://qmind.ca/wp-content/uploads/2020/04/logo@1x.png" width="180" height="320" alt="logo@1x" caption="" data-width="original" data-scaling="no"></div>
# 				</div>
#
# 					</div>
# 				</div><div id="column_cfc0dc6df" class="column hide-for-mobile" data-xl-width="3" data-md-width="3" data-lg-width="3" data-valign="center">
# 					<div class="content-wrapper">
#
# 				<div id="content_5be69b046" class="column-content hide-for-mobile hide-for-tablet-portrait" data-module="image">
# 					<div class="ce-image" data-align="left"><img class="is-content" src="https://qmind.ca/wp-content/uploads/2020/05/logo_text.png" width="800" height="192" alt="logo_text" caption="" data-width="grid-width" data-scaling="no"></div>
# 				</div>
#
# 				<div id="content_2kl4qhxo2" class="column-content" data-module="spacer">
#
# 				<div class="spacer-container">
# 					<div class="is-content">
# 						<div class="spacer"><!-- horizontal spacer --></div>
# 					</div>
# 				</div>
#
# 				</div>
#
# 					</div>
# 				</div><div id="column_a5d683d74" class="column" data-xl-width="6" data-md-width="6" data-lg-width="6" data-valign="center">
# 					<div class="content-wrapper">
#
# 				<div id="content_2ef556c83" class="column-content" data-module="text">
# 					<div class="is-content"><p style="font-size: 0.944rem; line-height: 1.056rem;" data-mce-style="font-size: 0.944rem; line-height: 1.056rem;" data-font-size-xl="0.944rem" data-line-height-xl="1.056rem"><span style="color: rgb(162, 164, 171);" data-mce-style="color: rgb(162, 164, 171);"><span data-letter-spacing-xl="-0.006rem" style="letter-spacing: -0.006rem;" data-mce-style="letter-spacing: -0.006rem;">﻿</span>Queen’s Machine Intelligence and Neuroevolution Design<span>﻿</span></span></p></div>
# 				</div>
#
# 				<div id="content_ceada92a9" class="column-content" data-module="text">
# 					<div class="is-content"><p style="line-height: 1.444rem; font-size: 0.944rem;" data-mce-style="line-height: 1.444rem; font-size: 0.944rem;" data-line-height-xl="1.444rem" data-font-size-xl="0.944rem">Queen's AI Hub</p></div>
# 				</div>
#
# 				<div id="content_c6d5j5zdn" class="column-content" data-module="spacer">
#
# 				<div class="spacer-container">
# 					<div class="is-content">
# 						<div class="spacer"><!-- horizontal spacer --></div>
# 					</div>
# 				</div>
#
# 				</div>
#
# 					</div>
# 				</div></div><div id="row_ad99abc5c" class="row"><div id="column_63d203ae3" class="column hide-for-mobile spacer-column" data-xl-width="3" data-valign="top">
# 					<div class="content-wrapper">
#
# 					</div>
# 				</div><div id="column_dnxiqg5du" class="column" data-xl-width="4">
# 					<div class="content-wrapper">
#
# 				<div id="content_a8299d3b9" class="column-content" data-module="text">
# 					<div class="is-content"><p>QMIND is Canada’s largest undergraduate AI and machine learning organization with over 200 members and a portfolio that includes 30+ client-facing consulting teams, a published AI research wing, an extensive 14-week educational program, a first of its kind incubator program, and a 300 delegate conference held annually in Toronto, ON.</p></div>
# 				</div>
#
# 					</div>
# 				</div><div id="column_384bde99c" class="column" data-xl-width="4" data-valign="top">
# 					<div class="content-wrapper">
#
# 				<div id="content_23ef22194" class="column-content hide-for-mobile hide-for-tablet-portrait" data-module="text">
# 					<div class="is-content"><p>QMIND focuses heavily on the production of computer-based models that use neural networks to automate or develop unique solutions to real-world problems. Breeding a culture of permanence and dedication, emphasizing low turnover rates amongst its members, and having a deliberate approach to growth ensures that QMIND will continue to flourish in future years.</p></div>
# 				</div>
#
# 					</div>
# 				</div></div></div>
# 					</section>
#
# 					<section id="section_95f0c7b49" class="content-block reveal" data-column-mode-sm="single" data-column-mode-xs="single" data-sr-id="3" style="; visibility: visible;  -webkit-transform: translateY(5px) scale(1); opacity: 0;transform: translateY(5px) scale(1); opacity: 0;">
# 						<div class="container"><div id="row_049dbddd0" class="row"><div id="column_4d2018e10" class="column" data-xl-width="6">
# 					<div class="content-wrapper">
#
# 				<div id="content_67c431fd9" class="column-content counter0225" data-module="text">
# 					<div class="is-content"><h2>171</h2></div>
# 				</div>
#
# 				<div id="content_jwddrrc4o" class="column-content counter-0-225" data-module="text">
# 					<div class="is-content"><h2 style="font-size: 1.333rem; line-height: 1.667rem;" data-mce-style="font-size: 1.333rem; line-height: 1.667rem;" data-font-size-xl="1.333rem" data-line-height-xl="1.667rem">Hired Members</h2></div>
# 				</div>
#
# 				<div id="content_394nrd5lt" class="column-content counter-0-225" data-module="text">
# 					<div class="is-content"><p data-mce-style="font-size: 0.889rem; line-height: 1.5rem;" style="font-size: 0.889rem; line-height: 1.5rem;" data-font-size-xl="0.889rem" data-line-height-xl="1.500rem">Since its creation in 2018, QMIND has increased from hiring 35 members to 225 members—more than a six-fold increase in just two and a half years!</p></div>
# 				</div>
#
# 					</div>
# 				</div><div id="column_5h0y4l0c1" class="column" data-xl-width="6">
# 					<div class="content-wrapper">
#
# 				<div id="content_7pyr0305v" class="column-content counter040" data-module="text">
# 					<div class="is-content"><h2><span style="color: rgb(0, 0, 0);" data-mce-style="color: rgb(0, 0, 0);"><strong>0</strong></span></h2></div>
# 				</div>
#
# 				<div id="content_pdni1gtel" class="column-content counter-0-225" data-module="text">
# 					<div class="is-content"><h2 style="font-size: 1.333rem; line-height: 1.667rem;" data-mce-style="font-size: 1.333rem; line-height: 1.667rem;" data-font-size-xl="1.333rem" data-line-height-xl="1.667rem">Directors and Project Managers</h2></div>
# 				</div>
#
# 				<div id="content_asv4z4zx4" class="column-content counter-0-225" data-module="text">
# 					<div class="is-content"><p data-mce-style="font-size: 0.889rem; line-height: 1.5rem;" style="font-size: 0.889rem; line-height: 1.5rem;" data-font-size-xl="0.889rem" data-line-height-xl="1.500rem">QMIND's Managing Directors, Executive Directors, and Project Managers —40 in total— are working behind the scenes to orchestrate and lead over 200 members.</p></div>
# 				</div>
#
# 					</div>
# 				</div></div></div>
# 					</section>
#
# 					<section id="section_cs8h3ni9h" class="content-block reveal" data-column-mode-sm="single" data-column-mode-xs="single" data-sr-id="4" style="; visibility: visible;  -webkit-transform: translateY(5px) scale(1); opacity: 0;transform: translateY(5px) scale(1); opacity: 0;">
# 						<div class="container"><div id="row_c92d1oxmw" class="row"><div id="column_r417lrdah" class="column" data-xl-width="6">
# 					<div class="content-wrapper">
#
# 				<div id="content_nqedycl6a" class="column-content counter031" data-module="text">
# 					<div class="is-content"><h2><span style="color: rgb(0, 0, 0);" data-mce-style="color: rgb(0, 0, 0);"><strong>0</strong></span></h2></div>
# 				</div>
#
# ...
# 				</div>
#
# 				<div id="content_bo4j5oyvx" class="column-content underline-links" data-module="text">
# 					<div class="is-content"><p style="text-align: justify; line-height: 1.333rem;" data-mce-style="text-align: justify; line-height: 1.333rem;" data-line-height-xl="1.333rem"><a data-mce-href="https://www.youtube.com/channel/UC69LsGj99FSN8cdP_Igs0XA" href="https://www.youtube.com/channel/UC69LsGj99FSN8cdP_Igs0XA" target="_blank" rel="noopener" data-mce-selected="1">Youtube<span style="letter-spacing: 0.022rem;" data-mce-style="letter-spacing: 0.022rem;" data-letter-spacing-xl="0.022rem"></span></a></p></div>
# 				</div>
#
# 					</div>
# 				</div></div></div>
# 					</section>
#
# 					<section id="section_6f3dbed49" class="content-block reveal" data-column-mode-sm="single" data-column-mode-xs="single" data-sr-id="39" style="; visibility: visible;  -webkit-transform: translateY(5px) scale(1); opacity: 0;transform: translateY(5px) scale(1); opacity: 0;">
# 						<div class="container"><div id="row_2b7080a22" class="row"><div id="column_9a5c25aa8" class="column" data-xl-width="12">
# 					<div class="content-wrapper">
#
# 				<div id="content_3b6df5729" class="column-content" data-module="text">
# 					<div class="is-content"><p style="text-align: center;" data-mce-style="text-align: center;"><span style="color: rgb(255, 255, 255);" data-mce-style="color: rgb(255, 255, 255);">© 2020 QMIND</span></p></div>
# 				</div>
#
# 					</div>
# 				</div></div></div>
# 					</section>
#
# 					</div>
# 				</div>
# 			</div>
# 		</div>
# 		<div class="pswp" tabindex="-1" role="dialog" aria-hidden="true">
# 	<div class="pswp__bg"></div>
# 	<div class="pswp__scroll-wrap">
# 		<div class="pswp__container">
# 			<div class="pswp__item"></div>
# 			<div class="pswp__item"></div>
# 			<div class="pswp__item"></div>
# 		</div>
# 		<div class="pswp__ui pswp__ui--hidden">
# 			<div class="pswp__top-bar">
# 				<div class="pswp__counter"></div>
# 				<button class="pswp__button pswp__button--close" title="Close (Esc)"></button>
# 				<button class="pswp__button pswp__button--share" title="Share"></button>
# 				<button class="pswp__button pswp__button--fs" title="Toggle fullscreen"></button>
# 				<button class="pswp__button pswp__button--zoom" title="Zoom in/out"></button>
# 				<div class="pswp__preloader">
# 					<div class="pswp__preloader__icn">
# 					  <div class="pswp__preloader__cut">
# 						<div class="pswp__preloader__donut"></div>
# 					  </div>
# 					</div>
# 				</div>
# 			</div>
# 			<div class="pswp__share-modal pswp__share-modal--hidden pswp__single-tap">
# 				<div class="pswp__share-tooltip"></div>
# 			</div>
# 			<button class="pswp__button pswp__button--arrow--left" title="Previous (arrow left)">
# 			</button>
# 			<button class="pswp__button pswp__button--arrow--right" title="Next (arrow right)">
# 			</button>
# 			<div class="pswp__caption">
# 				<div class="pswp__caption__center"></div>
# 			</div>
# 		</div>
# 	</div>
# </div>	<div class="back-to-top">
# 		<a class="semplice-event" data-event-type="helper" data-event="scrollToTop"><svg version="1.1" id="Ebene_1" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" x="0px" y="0px" width="53px" height="20px" viewBox="0 0 53 20" enable-background="new 0 0 53 20" xml:space="preserve">
# <g id="Ebene_3">
# </g>
# <g>
# 	<polygon points="43.886,16.221 42.697,17.687 26.5,4.731 10.303,17.688 9.114,16.221 26.5,2.312 	"></polygon>
# </g>
# </svg>
# </a>
# 	</div>
# 	<script type="text/javascript" src="https://qmind.ca/wp-content/themes/semplice5/assets/js/frontend.scripts.min.js?ver=5.1.1" id="semplice-frontend-scripts-js"></script>
# <script type="text/javascript" id="mediaelement-core-js-before">
# var mejsL10n = {"language":"en","strings":{"mejs.download-file":"Download File","mejs.install-flash":"You are using a browser that does not have Flash player enabled or installed. Please turn on your Flash player plugin or download the latest version from https:\/\/get.adobe.com\/flashplayer\/","mejs.fullscreen":"Fullscreen","mejs.play":"Play","mejs.pause":"Pause","mejs.time-slider":"Time Slider","mejs.time-help-text":"Use Left\/Right Arrow keys to advance one second, Up\/Down arrows to advance ten seconds.","mejs.live-broadcast":"Live Broadcast","mejs.volume-help-text":"Use Up\/Down Arrow keys to increase or decrease volume.","mejs.unmute":"Unmute","mejs.mute":"Mute","mejs.volume-slider":"Volume Slider","mejs.video-player":"Video Player","mejs.audio-player":"Audio Player","mejs.captions-subtitles":"Captions\/Subtitles","mejs.captions-chapters":"Chapters","mejs.none":"None","mejs.afrikaans":"Afrikaans","mejs.albanian":"Albanian","mejs.arabic":"Arabic","mejs.belarusian":"Belarusian","mejs.bulgarian":"Bulgarian","mejs.catalan":"Catalan","mejs.chinese":"Chinese","mejs.chinese-simplified":"Chinese (Simplified)","mejs.chinese-traditional":"Chinese (Traditional)","mejs.croatian":"Croatian","mejs.czech":"Czech","mejs.danish":"Danish","mejs.dutch":"Dutch","mejs.english":"English","mejs.estonian":"Estonian","mejs.filipino":"Filipino","mejs.finnish":"Finnish","mejs.french":"French","mejs.galician":"Galician","mejs.german":"German","mejs.greek":"Greek","mejs.haitian-creole":"Haitian Creole","mejs.hebrew":"Hebrew","mejs.hindi":"Hindi","mejs.hungarian":"Hungarian","mejs.icelandic":"Icelandic","mejs.indonesian":"Indonesian","mejs.irish":"Irish","mejs.italian":"Italian","mejs.japanese":"Japanese","mejs.korean":"Korean","mejs.latvian":"Latvian","mejs.lithuanian":"Lithuanian","mejs.macedonian":"Macedonian","mejs.malay":"Malay","mejs.maltese":"Maltese","mejs.norwegian":"Norwegian","mejs.persian":"Persian","mejs.polish":"Polish","mejs.portuguese":"Portuguese","mejs.romanian":"Romanian","mejs.russian":"Russian","mejs.serbian":"Serbian","mejs.slovak":"Slovak","mejs.slovenian":"Slovenian","mejs.spanish":"Spanish","mejs.swahili":"Swahili","mejs.swedish":"Swedish","mejs.tagalog":"Tagalog","mejs.thai":"Thai","mejs.turkish":"Turkish","mejs.ukrainian":"Ukrainian","mejs.vietnamese":"Vietnamese","mejs.welsh":"Welsh","mejs.yiddish":"Yiddish"}};
# </script>
# <script type="text/javascript" src="https://qmind.ca/wp-includes/js/mediaelement/mediaelement-and-player.min.js?ver=4.2.13-9993131" id="mediaelement-core-js"></script>
# <script type="text/javascript" src="https://qmind.ca/wp-includes/js/mediaelement/mediaelement-migrate.min.js?ver=5.5" id="mediaelement-migrate-js"></script>
# <script type="text/javascript" id="mediaelement-js-extra">
# /* <![CDATA[ */
# var _wpmejsSettings = {"pluginPath":"\/wp-includes\/js\/mediaelement\/","classPrefix":"mejs-","stretching":"responsive"};
# /* ]]> */
# </script>
# <script type="text/javascript" id="semplice-frontend-js-js-extra">
# /* <![CDATA[ */
# var semplice = {"default_api_url":"https:\/\/qmind.ca\/wp-json","semplice_api_url":"https:\/\/qmind.ca\/wp-json\/semplice\/v1\/frontend","template_dir":"https:\/\/qmind.ca\/wp-content\/themes\/semplice5","category_base":"\/category\/","tag_base":"\/tag\/","nonce":"2103a3b3cc","frontend_mode":"dynamic","static_transitions":"disabled","site_name":"QMIND","base_url":"https:\/\/qmind.ca","frontpage_id":"217","blog_home":"https:\/\/qmind.ca","blog_navbar":"","sr_status":"enabled","blog_sr_status":"enabled","is_preview":"","password_form":"\r\n<div class=\"post-password-form\">\r\n\t<div class=\"inner\">\r\n\t\t<form action=\"https:\/\/qmind.ca\/wp-login.php?action=postpass\" method=\"post\">\r\n\t\t\t<div class=\"password-lock\"><svg xmlns=\"http:\/\/www.w3.org\/2000\/svg\" width=\"35\" height=\"52\" viewBox=\"0 0 35 52\">\r\n  <path id=\"Form_1\" data-name=\"Form 1\" d=\"M31.3,25.028H27.056a0.755,0.755,0,0,1-.752-0.757V14.654a8.8,8.8,0,1,0-17.608,0v9.616a0.755,0.755,0,0,1-.752.757H3.7a0.755,0.755,0,0,1-.752-0.757V14.654a14.556,14.556,0,1,1,29.111,0v9.616A0.755,0.755,0,0,1,31.3,25.028Zm-3.495-1.514h2.743V14.654a13.051,13.051,0,1,0-26.1,0v8.859H7.192V14.654a10.309,10.309,0,1,1,20.617,0v8.859Zm4.43,28.475H2.761A2.77,2.77,0,0,1,0,49.213V25.28a1.763,1.763,0,0,1,1.755-1.766H33.242A1.763,1.763,0,0,1,35,25.28V49.213A2.77,2.77,0,0,1,32.239,51.988ZM1.758,25.028a0.252,0.252,0,0,0-.251.252V49.213a1.259,1.259,0,0,0,1.254,1.262H32.239a1.259,1.259,0,0,0,1.254-1.262V25.28a0.252,0.252,0,0,0-.251-0.252H1.758ZM20.849,43h-6.7a0.75,0.75,0,0,1-.61-0.314,0.763,0.763,0,0,1-.1-0.682l1.471-4.44a4.1,4.1,0,1,1,5.184,0L21.563,42a0.763,0.763,0,0,1-.1.682A0.75,0.75,0,0,1,20.849,43ZM15.2,41.487H19.8l-1.319-3.979a0.76,0.76,0,0,1,.33-0.891,2.6,2.6,0,1,0-2.633,0,0.76,0.76,0,0,1,.33.891Z\"\/>\r\n<\/svg>\r\n<\/div>\r\n\t\t\t<p>This content is protected. <br \/><span>To view, please enter the password.<\/span><\/p>\r\n\t\t\t<div class=\"input-fields\">\r\n\t\t\t\t<input name=\"post_password\" class=\"post-password-input\" type=\"password\" size=\"20\" maxlength=\"20\" placeholder=\"Enter password\" \/><a class=\"post-password-submit semplice-event\" data-event-type=\"helper\" data-event=\"postPassword\" data-id=\"217\">Submit<\/a>\t\t\t<\/div>\r\n\t\t<\/form>\r\n\t<\/div>\r\n<\/div>\r\n\r\n","portfolio_order":[152,224,193,198],"gallery":{"prev":"<svg version=\"1.1\" id=\"Ebene_1\" xmlns=\"http:\/\/www.w3.org\/2000\/svg\" xmlns:xlink=\"http:\/\/www.w3.org\/1999\/xlink\" x=\"0px\" y=\"0px\"\n\twidth=\"18px\" height=\"40px\"  viewBox=\"0 0 18 40\" enable-background=\"new 0 0 18 40\" xml:space=\"preserve\">\n<g id=\"Ebene_2\">\n\t<g>\n\t\t<polygon points=\"16.3,40 0.3,20 16.3,0 17.7,1 2.5,20 17.7,39 \t\t\"\/>\n\t<\/g>\n<\/g>\n<\/svg>\n","next":"<svg version=\"1.1\" id=\"Ebene_1\" xmlns=\"http:\/\/www.w3.org\/2000\/svg\" xmlns:xlink=\"http:\/\/www.w3.org\/1999\/xlink\" x=\"0px\" y=\"0px\"\n\twidth=\"18px\" height=\"40px\" viewBox=\"0 0 18 40\" enable-background=\"new 0 0 18 40\" xml:space=\"preserve\">\n<g id=\"Ebene_2\">\n\t<g>\n\t\t<polygon points=\"0.3,39 15.5,20 0.3,1 1.7,0 17.7,20 1.7,40 \t\t\"\/>\n\t<\/g>\n<\/g>\n<\/svg>\n"},"menus":{"nav_ruothfxma":{"html":"\r\n\t\t\t\t\t\t<header class=\"nav_ruothfxma semplice-navbar active-navbar non-sticky-nav  cover-transparent\" data-cover-transparent=\"enabled\" data-bg-overlay-visibility=\"hidden\" data-mobile-fallback=\"enabled\">\r\n\t\t\t\t\t\t\t<div class=\"container\" data-nav=\"logo-left-menu-right\">\r\n\t\t\t\t\t\t\t\t<div class=\"navbar-inner menu-type-text\" data-xl-width=\"12\" data-navbar-type=\"container\">\r\n\t\t\t\t\t\t\t\t\t<div class=\"logo navbar-left\"><a href=\"https:\/\/qmind.ca\" title=\"QMIND\"><img src=\"https:\/\/qmind.ca\/wp-content\/uploads\/2020\/04\/logo_text@1x.png\" alt=\"logo\"><\/a><\/div>\r\n\t\t\t\t\t\t\t\t\t<nav class=\"standard navbar-right\" data-font=\"font_l8n6lam2f\"><ul class=\"menu\"><li id=\"menu-item-179\" class=\"menu-item menu-item-type-custom menu-item-object-custom menu-item-1 ...
# /* ]]> */
# </script>
# <script type="text/javascript" src="https://qmind.ca/wp-content/themes/semplice5/assets/js/frontend.min.js?ver=5.1.1" id="semplice-frontend-js-js"></script>
# <script type="text/javascript" src="https://qmind.ca/wp-includes/js/wp-embed.min.js?ver=5.5" id="wp-embed-js"></script>
# <script type="text/javascript" id="semplice-custom-javascript">(function($) {
# $(document).on('click', 'a[href^="#"]', function(e) {
#  var id = $(this).attr('href');
#  var $id = $(id);
#  if ($id.length === 0) {
#  return;
#  }
#  e.preventDefault();
#  var pos = $id.offset().top;
#  $('body, html').animate({scrollTop: pos},800);
#  $( "body.open-menu #overlay-menu .menu-icon" ).trigger( "click" );
# });
# })(jQuery);
#
# function animateValue(id, start, end, duration) {
#     var range = end - start;
#     var current = start;
#     var increment = end > start? 1 : -1;
#     var stepTime = Math.abs(Math.floor(duration / range));
# 	obj = document.getElementsByClassName(id)[0].childNodes[1].childNodes[0];
#     // var obj = document.getElementById(id);
#     var timer = setInterval(function() {
#         current += increment;
#         obj.innerHTML = current;
#         if (current == end) {
#             clearInterval(timer);
#         }
#     }, stepTime);
# }
#
# function t1() {
# 	return new Promise(resolve => {
# 	  setTimeout(() => {
# 		animateValue("counter0225", 0, 225, 2000);
# 		resolve("done 1");
# 	  }, 2000);
# 	});
# }
# function t2() {
# 	return new Promise(resolve => {
# 	  setTimeout(() => {
# 		animateValue("counter040", 0, 40, 2000);
# 		resolve("done 2");
# 	  }, 2000);
# 	});
# }
# function t3() {
# 	return new Promise(resolve => {
# 	  setTimeout(() => {
# 		animateValue("counter031", 0, 31, 2000);
# 		resolve("done 3");
# 	  }, 2000);
# 	});
# }
# function t4() {
# 	return new Promise(resolve => {
# 	  setTimeout(() => {
# 		animateValue("counter014", 0, 14, 2000);
# 		resolve("done 4");
# 	  }, 2000);
# 	});
# }
# async function allTasks() {
#   await t1();
#   await t2();
#   await t3();
#   await t4();
# }
#
# allTasks();</script>
# </body></html>

# %% [markdown]
# # Automated Testing
#
# Seleniums main industrial use is in automated testing of website functionality. This is not directly related to data science, but here is a tutorial if you are interested:
#
# https://www.youtube.com/watch?v=_JNeiGbAgL4
